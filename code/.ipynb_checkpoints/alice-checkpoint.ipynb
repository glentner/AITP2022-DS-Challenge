# %%
import pandas as pd

# %%
mydat = pd.read_csv("../../data/antarctica.csv")

# %%
mydat.shape
# Out:
# (800431, 28)

# %%
mydat.head()
# Out:
#        STATION        DATE  LATITUDE  LONGITUDE  ELEVATION      NAME  TEMP  \
# 0  61903099999  1950-07-03    -71.05      -10.9       37.0  UNKN, AY -39.5
# 1  61903099999  1950-07-04    -71.05      -10.9       37.0  UNKN, AY -43.5
# 2  61903099999  1950-07-05    -71.05      -10.9       37.0  UNKN, AY -39.2
# 3  61903099999  1950-07-06    -71.05      -10.9       37.0  UNKN, AY -34.0
# 4  61903099999  1950-07-07    -71.05      -10.9       37.0  UNKN, AY -36.0
#
#    TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES  ...  MXSPD   GUST   MAX  \
# 0                4 -43.0                4  ...    8.0  999.9 -24.0
# 1                4 -47.2                4  ...   11.1  999.9 -40.0
# 2                4 -42.7                4  ...   13.0  999.9 -29.0
# 3                4 -37.8                4  ...   15.0  999.9 -27.0
# 4                4 -39.5                4  ...   25.1  999.9 -31.0
#
#    MAX_ATTRIBUTES   MIN  MIN_ATTRIBUTES  PRCP  PRCP_ATTRIBUTES   SNDP  FRSHTT
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
mydat.head(30)
# Out:
#         STATION        DATE  LATITUDE  LONGITUDE  ELEVATION      NAME  TEMP  \
# 0   61903099999  1950-07-03    -71.05      -10.9       37.0  UNKN, AY -39.5
# 1   61903099999  1950-07-04    -71.05      -10.9       37.0  UNKN, AY -43.5
# 2   61903099999  1950-07-05    -71.05      -10.9       37.0  UNKN, AY -39.2
# 3   61903099999  1950-07-06    -71.05      -10.9       37.0  UNKN, AY -34.0
# 4   61903099999  1950-07-07    -71.05      -10.9       37.0  UNKN, AY -36.0
# 5   61903099999  1950-07-08    -71.05      -10.9       37.0  UNKN, AY -27.3
# 6   61903099999  1950-07-09    -71.05      -10.9       37.0  UNKN, AY -18.0
# 7   61903099999  1950-07-10    -71.05      -10.9       37.0  UNKN, AY  -8.5
# 8   61903099999  1950-07-12    -71.05      -10.9       37.0  UNKN, AY -28.0
# 9   61903099999  1950-07-13    -71.05      -10.9       37.0  UNKN, AY -28.8
# 10  61903099999  1950-07-14    -71.05      -10.9       37.0  UNKN, AY -33.7
# ...

# %%
mydat['ELEVATION'].isnull().sum()
# Out:
# 2496

# %%
mydat.head()
# Out:
#        STATION        DATE  LATITUDE  LONGITUDE  ELEVATION      NAME  TEMP  \
# 0  61903099999  1950-07-03    -71.05      -10.9       37.0  UNKN, AY -39.5
# 1  61903099999  1950-07-04    -71.05      -10.9       37.0  UNKN, AY -43.5
# 2  61903099999  1950-07-05    -71.05      -10.9       37.0  UNKN, AY -39.2
# 3  61903099999  1950-07-06    -71.05      -10.9       37.0  UNKN, AY -34.0
# 4  61903099999  1950-07-07    -71.05      -10.9       37.0  UNKN, AY -36.0
#
#    TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES    SLP  SLP_ATTRIBUTES    STP  \
# 0                4 -43.0                4  993.0               4  999.9
# 1                4 -47.2                4  987.3               4  999.9
# 2                4 -42.7                4  984.1               4  999.9
# 3                4 -37.8                4  988.2               4  999.9
# 4                4 -39.5                4  992.0               4  999.9
#
#    STP_ATTRIBUTES  VISIB  VISIB_ATTRIBUTES  WDSP  WDSP_ATTRIBUTES  MXSPD  \
# ...

# %%
mydat.tail()
# Out:
#             STATION        DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 800426  89879099999  2022-03-23 -71.883333      171.2       30.0
# 800427  89879099999  2022-03-24 -71.883333      171.2       30.0
# 800428  89879099999  2022-03-25 -71.883333      171.2       30.0
# 800429  89879099999  2022-03-26 -71.883333      171.2       30.0
# 800430  89879099999  2022-03-27 -71.883333      171.2       30.0
#
#                      NAME  TEMP  TEMP_ATTRIBUTES    DEWP  DEWP_ATTRIBUTES  \
# 800426  POSSESSION IS, AY  24.9               24  9999.9                0
# 800427  POSSESSION IS, AY  23.1               24  9999.9                0
# 800428  POSSESSION IS, AY  19.8               24  9999.9                0
# 800429  POSSESSION IS, AY  21.7               24  9999.9                0
# 800430  POSSESSION IS, AY  17.7               22  9999.9                0
#
#            SLP  SLP_ATTRIBUTES    STP  STP_ATTRIBUTES  VISIB  \
# 800426  9999.9               0  972.8              24  999.9
# ...

# %%
mydat['STATION'].value_counts()
# Out:
# 89009090001    17854
# 89055099999    16595
# 88963099999    15918
# 89611099999    15589
# 89571099999    15565
#                ...
# 85995099999       19
# 89627099999        9
# 89970099999        8
# 89971099999        4
# 89544099999        1
# Name: STATION, Length: 199, dtype: int64

# %%
print(mydat['DATE'].dtypes)
# Out:
# object

# %%
temp = pd.to_datetime(mydat['DATE'])

# %%
mydat['DATE'] = temp

# %%
print(temp.dtypes)
# Out:
# datetime64[ns]

# %%
mydat.head()
# Out:
#        STATION       DATE  LATITUDE  LONGITUDE  ELEVATION      NAME  TEMP  \
# 0  61903099999 1950-07-03    -71.05      -10.9       37.0  UNKN, AY -39.5
# 1  61903099999 1950-07-04    -71.05      -10.9       37.0  UNKN, AY -43.5
# 2  61903099999 1950-07-05    -71.05      -10.9       37.0  UNKN, AY -39.2
# 3  61903099999 1950-07-06    -71.05      -10.9       37.0  UNKN, AY -34.0
# 4  61903099999 1950-07-07    -71.05      -10.9       37.0  UNKN, AY -36.0
#
#    TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES    SLP  SLP_ATTRIBUTES    STP  \
# 0                4 -43.0                4  993.0               4  999.9
# 1                4 -47.2                4  987.3               4  999.9
# 2                4 -42.7                4  984.1               4  999.9
# 3                4 -37.8                4  988.2               4  999.9
# 4                4 -39.5                4  992.0               4  999.9
#
#    STP_ATTRIBUTES  VISIB  VISIB_ATTRIBUTES  WDSP  WDSP_ATTRIBUTES  MXSPD  \
# ...

# %%
mydat1 = mydat[mydat['SLP'] != 999.9]

# %%
mydat2 = mydat1[mydat1['SLP'] != 9999.9]

# %%
mydat3 = mydat2[mydat2['STP'] != 999.9]

# %%
mydat4 = mydat3[mydat3['STP'] != 9999.9]

# %%
mydat5 = mydat4[mydat4['DEWP'] != 999.9]

# %%
mydat6 = mydat5[mydat5['DEWP'] != 9999.9]

# %%
mydat7 = mydat6[mydat6['VISIB'] != 999.9]

# %%
mydat8 = mydat7[mydat7['VISIB'] != 9999.9]

# %%
mydat9 = mydat8[mydat8['WDSP'] != 999.9]

# %%
mydat10 = mydat9[mydat9['WDSP'] != 9999.9]

# %%
mydat11 = mydat10[mydat10['MXSPD'] != 999.9]

# %%
mydat12 = mydat11[mydat11['MXSPD'] != 9999.9]

# %%
mydat13 = mydat12[mydat12['GUST'] != 999.9]

# %%
mydat14 = mydat13[mydat13['GUST'] != 9999.9]

# %%
mydat15 = mydat14[mydat14['SNDP'] != 999.9]

# %%
mydat16 = mydat15[mydat15['SNDP'] != 9999.9]

# %%
mydat16
# Out:
#             STATION       DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 280929  89055099999 1999-11-05 -64.233333 -56.716667      208.0
# 280967  89055099999 1999-12-17 -64.233333 -56.716667      208.0
# 315711  89055099999 2001-11-27 -64.233333 -56.716667      208.0
# 315733  89055099999 2001-12-19 -64.233333 -56.716667      208.0
# 315744  89055099999 2001-12-30 -64.233333 -56.716667      208.0
# ...             ...        ...        ...        ...        ...
# 778208  89063099999 2021-05-08 -65.250000 -64.266667       11.0
# 778218  89063099999 2021-05-18 -65.250000 -64.266667       11.0
# 778227  89063099999 2021-05-27 -65.250000 -64.266667       11.0
# 778257  89063099999 2021-06-26 -65.250000 -64.266667       11.0
# 778280  89063099999 2021-07-19 -65.250000 -64.266667       11.0
#
#                                            NAME  TEMP  TEMP_ATTRIBUTES  DEWP  \
# 280929  BASE MARAMBIO CENTRO MET. ANTARTICO, AY  22.0                4  20.8
# ...

# %%
print(mydat['DATE'].dtypes)
# Out:
# datetime64[ns]

# %%
mydat['YEAR'] = mydat['DATE'].dt.year

# %%
mydat.head()
# Out:
#        STATION       DATE  LATITUDE  LONGITUDE  ELEVATION      NAME  TEMP  \
# 0  61903099999 1950-07-03    -71.05      -10.9       37.0  UNKN, AY -39.5
# 1  61903099999 1950-07-04    -71.05      -10.9       37.0  UNKN, AY -43.5
# 2  61903099999 1950-07-05    -71.05      -10.9       37.0  UNKN, AY -39.2
# 3  61903099999 1950-07-06    -71.05      -10.9       37.0  UNKN, AY -34.0
# 4  61903099999 1950-07-07    -71.05      -10.9       37.0  UNKN, AY -36.0
#
#    TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES    SLP  SLP_ATTRIBUTES    STP  \
# 0                4 -43.0                4  993.0               4  999.9
# 1                4 -47.2                4  987.3               4  999.9
# 2                4 -42.7                4  984.1               4  999.9
# 3                4 -37.8                4  988.2               4  999.9
# 4                4 -39.5                4  992.0               4  999.9
#
#    STP_ATTRIBUTES  VISIB  VISIB_ATTRIBUTES  WDSP  WDSP_ATTRIBUTES  MXSPD  \
# ...

# %%
mydat['MONTH'] = mydat['DATE'].dt.month

# %%
mydat['DAY'] = mydat['DATE'].dt.day

# %%
mydat.head()
# Out:
#        STATION       DATE  LATITUDE  LONGITUDE  ELEVATION      NAME  TEMP  \
# 0  61903099999 1950-07-03    -71.05      -10.9       37.0  UNKN, AY -39.0
# 1  61903099999 1950-07-04    -71.05      -10.9       37.0  UNKN, AY -43.0
# 2  61903099999 1950-07-05    -71.05      -10.9       37.0  UNKN, AY -39.0
# 3  61903099999 1950-07-06    -71.05      -10.9       37.0  UNKN, AY -34.0
# 4  61903099999 1950-07-07    -71.05      -10.9       37.0  UNKN, AY -36.0
#
#    TEMP_ATTRIBUTES  DEWP  DEWP_ATTRIBUTES    SLP  SLP_ATTRIBUTES    STP  \
# 0                4 -43.0                4  993.0               4  999.9
# 1                4 -47.2                4  987.3               4  999.9
# 2                4 -42.7                4  984.1               4  999.9
# 3                4 -37.8                4  988.2               4  999.9
# 4                4 -39.5                4  992.0               4  999.9
#
#    STP_ATTRIBUTES  VISIB  VISIB_ATTRIBUTES  WDSP  WDSP_ATTRIBUTES  MXSPD  \
# ...

# %%
mydat.groupby('YEAR')['TEMP'].mean()
# Out:
# YEAR
# 1950     2.348718
# 1951    -0.110653
# 1952    22.760000
# 1953    24.031646
# 1954    22.721849
#           ...
# 2018     2.739822
# 2019    -2.827040
# 2020    -2.122210
# 2021    -5.287694
# 2022    13.326987
# Name: TEMP, Length: 73, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
mydat16
# Out:
#             STATION       DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 280929  89055099999 1999-11-05 -64.233333 -56.716667      208.0
# 280967  89055099999 1999-12-17 -64.233333 -56.716667      208.0
# 315711  89055099999 2001-11-27 -64.233333 -56.716667      208.0
# 315733  89055099999 2001-12-19 -64.233333 -56.716667      208.0
# 315744  89055099999 2001-12-30 -64.233333 -56.716667      208.0
# ...             ...        ...        ...        ...        ...
# 778208  89063099999 2021-05-08 -65.250000 -64.266667       11.0
# 778218  89063099999 2021-05-18 -65.250000 -64.266667       11.0
# 778227  89063099999 2021-05-27 -65.250000 -64.266667       11.0
# 778257  89063099999 2021-06-26 -65.250000 -64.266667       11.0
# 778280  89063099999 2021-07-19 -65.250000 -64.266667       11.0
#
#                                            NAME  TEMP  TEMP_ATTRIBUTES  DEWP  \
# 280929  BASE MARAMBIO CENTRO MET. ANTARTICO, AY  22.0                4  20.8
# ...

# %%
mydat.groupby(mydat[mydat['MONTH'] == 3]['YEAR'])['TEMP'].mean().plot()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
temp = mydat[mydat['YEAR'] == 2022]

# %%
temp.groupby(temp[temp['MONTH'] == 3]['DAY'])['TEMP'].mean().plot()
# Out:
# <AxesSubplot:xlabel='DAY'>

# %%
temp1 = mydat[mydat['YEAR'] != 2022]

# %%
temp1.groupby(temp1[temp1['MONTH'] == 3]['DAY'])['TEMP'].mean().plot()
# Out:
# <AxesSubplot:xlabel='DAY'>

# %% [markdown]
# ## Challenge 5

# %%
dat1 = mydat['STATION'].unique()

# %%
len(dat1)
# Out:
# 199

# %% [markdown]
# There are 199 stations total in Antarctica.

# %%
len(mydat[mydat['YEAR'] ==  2022]['STATION'].unique())
# Out:
# 64

# %% [markdown]
# import plotly.express as pxThere are 64 current stations active today.

# %%
import plotly.express as px

# %%
mydat['TEMP'] = mydat['TEMP'].astype(float)

# %%
df = mydat.groupby('STATION')

# %%
df.head()
# Out:
#             STATION       DATE   LATITUDE  LONGITUDE  ELEVATION  \
# 0       61903099999 1950-07-03 -71.050000 -10.900000       37.0
# 1       61903099999 1950-07-04 -71.050000 -10.900000       37.0
# 2       61903099999 1950-07-05 -71.050000 -10.900000       37.0
# 3       61903099999 1950-07-06 -71.050000 -10.900000       37.0
# 4       61903099999 1950-07-07 -71.050000 -10.900000       37.0
# ...             ...        ...        ...        ...        ...
# 703414  85987199999 2018-02-07 -62.983333 -60.683333       12.0
# 703415  85987199999 2018-02-08 -62.983333 -60.683333       12.0
# 703416  85987199999 2018-02-09 -62.983333 -60.683333       12.0
# 703417  85987199999 2018-02-10 -62.983333 -60.683333       12.0
# 703418  85987199999 2018-02-11 -62.983333 -60.683333       12.0
#
#                            NAME  TEMP  TEMP_ATTRIBUTES    DEWP  \
# 0                      UNKN, AY -39.0                4   -43.0
# 1                      UNKN, AY -43.0                4   -47.2
# ...

# %%
df = mydat.dropna().groupby('STATION')

# %%
mydat.columns
# Out:
# Index(['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'NAME', 'TEMP',
#        'TEMP_ATTRIBUTES', 'DEWP', 'DEWP_ATTRIBUTES', 'SLP', 'SLP_ATTRIBUTES',
#        'STP', 'STP_ATTRIBUTES', 'VISIB', 'VISIB_ATTRIBUTES', 'WDSP',
#        'WDSP_ATTRIBUTES', 'MXSPD', 'GUST', 'MAX', 'MAX_ATTRIBUTES', 'MIN',
#        'MIN_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES', 'SNDP', 'FRSHTT', 'YEAR',
#        'MONTH'],
#       dtype='object')

# %%
my_dat_plot_view = mydat[['STATION', 'LATITUDE', 'LONGITUDE']]
my_dat_plot_view
# Out:
#             STATION   LATITUDE  LONGITUDE
# 0       61903099999 -71.050000      -10.9
# 1       61903099999 -71.050000      -10.9
# 2       61903099999 -71.050000      -10.9
# 3       61903099999 -71.050000      -10.9
# 4       61903099999 -71.050000      -10.9
# ...             ...        ...        ...
# 800426  89879099999 -71.883333      171.2
# 800427  89879099999 -71.883333      171.2
# 800428  89879099999 -71.883333      171.2
# 800429  89879099999 -71.883333      171.2
# 800430  89879099999 -71.883333      171.2
#
# [800431 rows x 3 columns]

# %%
fig = px.scatter_geo(lat=list(mydat['LATITUDE']), lon=list(mydat['LONGITUDE']), scope = 'world', width = 800, height = 600)
fig.update_layout(geo = dict(projection_scale=7, center=dict(lat=df['LATITUDE'].iloc[0], lon=df['LONGITUDE'].iloc[0])))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [137], in <cell line: 2>()
#       1 fig = px.scatter_geo(lat=list(mydat['LATITUDE']), lon=list(mydat['LONGITUDE']), scope = 'world', width = 800, height = 600)
# ----> 2 fig.update_layout(geo = dict(projection_scale=7, center=dict(lat=df['LATITUDE'].iloc[0], lon=df['LONGITUDE'].iloc[0])))
#       3 fig.show()
#
# File ~/.conda/envs/cent7/2020.11-py38/my_env/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'iloc'

# %%
def plot_stations(df, *stations):
    fig = px.scatter_geo(df, lat= 'LATITUDE', lon="LONGITUDE", scope = 'world', width = 800, height = 600)
    fig.update_layout(geo = dict(projection_scale=7, center=dict(lat=df['LATITUDE'].iloc[0], lon=df['LONGITUDE'].iloc[0])))
    fig.plot()

# %%
plot_stations(mydat, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [115], in <cell line: 1>()
# ----> 1 plot_stations(mydat, 1)
#
# Input In [114], in plot_stations(df, *stations)
#       2 fig = px.scatter_geo(df, lat= 'LATITUDE', lon="LONGITUDE", scope = 'world', width = 800, height = 600)
#       3 fig.update_layout(geo = dict(projection_scale=7, center=dict(lat=df['LATITUDE'].iloc[0], lon=df['LONGITUDE'].iloc[0])))
# ----> 4 fig.plot()
#
# AttributeError: 'Figure' object has no attribute 'plot'
